# %% [markdown]
# <center> <h2 style="background-color: DodgerBlue; padding: 10px;"> <span style="color:white">
# <br> BCS32: BROWN, Yuri M. <br>
# <br> NATURAL LANGUAGE PROCESSING <br>
# <br> ACTIVITY: MINI ACTIVITY 1 <br> <br>
# </span> </h2> </center>

# %%
# Install libraries
# !pip install nltk spacy

# %%
# Import Libraries
import nltk
import spacy
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from spacy.lang.en import English

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression

from sklearn.pipeline import make_pipeline
from nltk.stem import PorterStemmer, WordNetLemmatizer

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import classification_report

# Download NLTK Resources
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')

# Load SpaCy Model
nlp = English()
# Out:
# [nltk_data] Downloading package punkt_tab to C:\Users\sheila
# [nltk_data]     brown\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\sheila
# [nltk_data]     brown\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\sheila
# [nltk_data]     brown\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
## LIST: Given and New Sentences

# Given Sentences: Texts
texts = [
    "The movie was fantastic, I loved every moment of it",
    "The food was terrible, I would never eat there again",
    "I had a great time at the concert",
    "The service at the restaurant was horrible",
    "I really enjoyed the book",
    "The hotel room was dirty and uncomfortable",
    "I am very satisfied with my purchase",
    "The delivery was late and the package was damaged",
    "The customer support was very helpful",
    "I am disappointed with the quality of the product"
]

# Given Sentences: Labels
labels = [
    "Positive",
    "Negative",
    "Positive",
    "Negative",
    "Positive",
    "Negative",
    "Positive",
    "Negative",
    "Positive",
    "Negative"
]

# New Sentences: Texts
new_texts = [
    "The play was fantastically enjoyable; I adored each and every scene of it",
    "The coffee was terrifically awful; I would never consider drinking it again",
    "The festival was a greatly enjoyable experience",
    "The service at the hospital was horrendously poor",
    "I really enjoyed the movie.",
    "The train was delayed, and I missed my appointment",
    "He found the book extremely inspiring and motivating",
    "The constant noise from construction was unbearable",
    "Her speech was heartfelt, leaving the audience feeling uplifted",
    "I felt completely ignored during the entire meeting",
]

# New Sentences: labels
new_labels = [
    "Positive",
    "Negative",
    "Positive",
    "Negative",
    "Positive",
    "Negative",
    "Positive",
    "Negative",
    "Positive",
    "Negative"
]

# %% [markdown]
# <center> <h2 style="background-color: SlateBlue; padding: 10px;"> <span style="color:white">
# CHOOSE A VECTORIZER
# </span> </h2> </center>

# %%
# CountVectorizer: Create a pipeline for classification
model = make_pipeline(CountVectorizer(), MultinomialNB())
model.fit(texts, labels)
# Out:
# Pipeline(steps=[('countvectorizer', CountVectorizer()),
#                 ('multinomialnb', MultinomialNB())])

# %%
# TfidfVectorizer: Create a pipeline for classification
def clean_text(text):
    token = word_tokenize(text)    
    c_stopwords = set(stopwords.words('english'))    
    stemmer = PorterStemmer()
    lemmatizer = WordNetLemmatizer()    
    lemmatized_words = []
    stemmed_words = []
    
    for word in token:
        lower_word = word.lower()
        if lower_word not in c_stopwords:
            lemmatized_words.append(lemmatizer.lemmatize(lower_word))
    
    for word in lemmatized_words:
        stemmed_words.append(stemmer.stem(word))
    
    clean_text = ' '.join(stemmed_words)
    
    return clean_text

clean_texts = []
for text in texts:
    text = clean_text(text)
    clean_texts.append(text)

model = make_pipeline(TfidfVectorizer(stop_words='english'), MultinomialNB())
model.fit(clean_texts, labels)
# Out:
# Pipeline(steps=[('tfidfvectorizer', TfidfVectorizer(stop_words='english')),
#                 ('multinomialnb', MultinomialNB())])

# %%
# TfidfVectorizer + LogisticRegression: Create a pipeline for classification
def clean_text(text):
    token = word_tokenize(text)    
    c_stopwords = set(stopwords.words('english'))    
    stemmer = PorterStemmer()
    lemmatizer = WordNetLemmatizer()    
    lemmatized_words = []
    stemmed_words = []
    
    for word in token:
        lower_word = word.lower()
        if lower_word not in c_stopwords:
            lemmatized_words.append(lemmatizer.lemmatize(lower_word))
    
    for word in lemmatized_words:
        stemmed_words.append(stemmer.stem(word))
    
    clean_text = ' '.join(stemmed_words)
    
    return clean_text

clean_texts = []
for text in texts:
    text = clean_text(text)
    clean_texts.append(text)

model = make_pipeline(TfidfVectorizer(stop_words='english'), LogisticRegression(max_iter=200))
model.fit(clean_texts, labels)
# Out:
# Pipeline(steps=[('tfidfvectorizer', TfidfVectorizer(stop_words='english')),
#                 ('logisticregression', LogisticRegression(max_iter=200))])

# %% [markdown]
# <center> <h2 style="background-color: MediumSeaGreen; padding: 10px;"> <span style="color:white">
# USER-INPUT: TYPE NEW SENTENCES
# </span> </h2> </center>

# %%
# CountVectorizer: User-Input
user_input = input("Enter a text: ")
prediction = model.predict([user_input])
print("Predicted Sentiment: ", prediction[0], "\n")
# Out:
# Enter a text:  I felt completely ignored during the entire meeting
# Predicted Sentiment:  Negative

# %%
# TfidfVectorizer: User-Input
user_input = input("Enter a text: ")
user_input = clean_text(user_input)
prediction = model.predict([user_input])
print("Predicted Sentiment: ", prediction[0], "\n")
# Out:
# Enter a text:  Her speech was heartfelt, leaving the audience feeling uplifted
# Predicted Sentiment:  Negative

# %% [markdown]
# <center> <h2 style="background-color: Tomato; padding: 10px;"> <span style="color:white">
# EVALUATION METRICS
# </span> </h2> </center>

# %%
# CountVectorizer: Utilize evaluation metrics
def evaluate(texts, labels):
    predicted_labels = []
    
    for text in texts:
        prediction = model.predict([text])
        predicted_labels.append(prediction[0])
    
    print(predicted_labels)
    
    # Calculate evaluation metrics
    accuracy = accuracy_score(labels, predicted_labels)
    precision = precision_score(labels, predicted_labels, average='weighted')
    recall = recall_score(labels, predicted_labels, average='weighted')
    f1 = f1_score(labels, predicted_labels, average='weighted')
    
    print("Accuracy:", accuracy)
    print("Precision:", precision)
    print("Recall:", recall)
    print("F1-Score:", f1)

# %%
# TfidfVectorizer: Utilize evaluation metrics
def evaluate(texts, labels):
    predicted_labels = []
    
    for text in texts:
        text = clean_text(text)
        prediction = model.predict([text])
        predicted_labels.append(prediction[0])
    
    print(predicted_labels)
    
    # Calculate evaluation metrics
    accuracy = accuracy_score(labels, predicted_labels)
    precision = precision_score(labels, predicted_labels, average='weighted')
    recall = recall_score(labels, predicted_labels, average='weighted')
    f1 = f1_score(labels, predicted_labels, average='weighted')
    
    print("Accuracy:", accuracy)
    print("Precision:", precision)
    print("Recall:", recall)
    print("F1-Score:", f1)

# %%
# Evaluate Original Sentences
evaluate(texts, labels)
# Out:
# ['Positive', 'Negative', 'Positive', 'Negative', 'Positive', 'Negative', 'Positive', 'Negative', 'Positive', 'Negative']
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-Score: 1.0

# %%
# Evaluate New Sentences
evaluate(new_texts, new_labels)
# Out:
# ['Positive', 'Negative', 'Positive', 'Negative', 'Positive', 'Negative', 'Positive', 'Negative', 'Negative', 'Negative']
# Accuracy: 0.9
# Precision: 0.9166666666666667
# Recall: 0.9
# F1-Score: 0.898989898989899
